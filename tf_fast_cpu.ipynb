# %% [markdown]
# <a href="https://colab.research.google.com/github/365Gallery/ML/blob/main/tf_fast_cpu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/lengstrom/fast-style-transfer.git
# Out:
# Cloning into 'fast-style-transfer'...
# remote: Enumerating objects: 1, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 239 (delta 0), reused 0 (delta 0), pack-reused 238
# Receiving objects: 100% (239/239), 11.02 MiB | 7.52 MiB/s, done.
# Resolving deltas: 100% (111/111), done.

# %%
cd fast-style-transfer/
# Out:
# /Users/bangyoon/00_2021sogang/365Gallery/fast-style-transfer

# %%
ls
# Out:
# README.md           evaluate.py         setup.sh*           style.py
# docs.md             examples/           src/                transform_video.py

# %%
# !./setup.sh
# Out:
# --2021-03-31 12:35:25--  http://www.vlfeat.org/matconvnet/models/beta16/imagenet-vgg-verydeep-19.mat
# Resolving www.vlfeat.org (www.vlfeat.org)... 64.90.48.57
# Connecting to www.vlfeat.org (www.vlfeat.org)|64.90.48.57|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://www.vlfeat.org/matconvnet/models/beta16/imagenet-vgg-verydeep-19.mat [following]
# --2021-03-31 12:35:26--  https://www.vlfeat.org/matconvnet/models/beta16/imagenet-vgg-verydeep-19.mat
# Connecting to www.vlfeat.org (www.vlfeat.org)|64.90.48.57|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 576042600 (549M)
# Saving to: ‘imagenet-vgg-verydeep-19.mat’
#
# imagenet-vgg-veryde 100%[===================>] 549.36M  5.03MB/s    in 2m 8s
#
# 2021-03-31 12:37:34 (4.28 MB/s) - ‘imagenet-vgg-verydeep-19.mat’ saved [576042600/576042600]
#
# --2021-03-31 12:37:34--  http://msvocds.blob.core.windows.net/coco2014/train2014.zip
# ...

# %%
# !pip list #tensorflow 없으니까 install
# Out:
# Package                            Version
# ---------------------------------- -------------------
# alabaster                          0.7.12
# anaconda-client                    1.7.2
# anaconda-navigator                 1.9.12
# anaconda-project                   0.8.3
# applaunchservices                  0.2.1
# appnope                            0.1.0
# appscript                          1.0.1
# argh                               0.26.2
# asgiref                            3.2.10
# asn1crypto                         1.3.0
# astroid                            2.3.3
# astropy                            4.0
# atomicwrites                       1.3.0
# attrs                              19.3.0
# autopep8                           1.4.4
# Babel                              2.8.0
# backcall                           0.1.0
# backports.functools-lru-cache      1.6.1
# backports.shutil-get-terminal-size 1.0.0
# backports.tempfile                 1.0
# ...

# %%
# !pip install tensorflow==2.4.1 --ignore-installed
# Out:
# ...
#      |████████████████████████████████| 173.9 MB 6.1 MB/s eta 0:00:011    |█████████████▋                  | 73.8 MB 12.2 MB/s eta 0:00:09
# ...
#   Using cached gast-0.3.3-py2.py3-none-any.whl (9.7 kB)
# ...
#      |████████████████████████████████| 462 kB 9.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.0 MB 12.8 MB/s eta 0:00:01
# ...
#   Using cached six-1.15.0-py2.py3-none-any.whl (10 kB)
# ...
#      |████████████████████████████████| 3.3 MB 9.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 129 kB 11.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 15.6 MB 8.2 MB/s eta 0:00:011
# ...
#   Using cached wrapt-1.12.1.tar.gz (27 kB)
# ...
#      |████████████████████████████████| 1.0 MB 9.7 MB/s eta 0:00:01
# ...
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# ...
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# ...
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# ...
#   Using cached termcolor-1.1.0.tar.gz (3.9 kB)
# ...

# %%
# !pip install moviepy==1.0.2
# Out:
# ...
#      |████████████████████████████████| 7.8 MB 1.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 22.5 MB 10.1 MB/s eta 0:00:01
# ...
#   Created wheel for moviepy: filename=moviepy-1.0.2-py3-none-any.whl size=110729 sha256=9d4d117f7d29b289bc441da7453c567f72fc65a1d4ce9962189c9bf5f4f3b61d
#   Stored in directory: /Users/bangyoon/Library/Caches/pip/wheels/f0/36/f2/32c37d2b7a4f04622ccec875f71ebf5f33f892cea410f26454
# ...
#   Created wheel for proglog: filename=proglog-0.1.9-py3-none-any.whl size=6147 sha256=1afa78cbd26033688a3f910bebf9a342f4ad469770414feb48ee289522a0edfc
#   Stored in directory: /Users/bangyoon/Library/Caches/pip/wheels/12/36/1f/dc61e6ac10781d63cf6fa045eb09fa613a667384e12cb6e6e0
# Successfully built moviepy proglog
# ...

# %%
cd .
# Out:
# /Users/bangyoon/00_2021sogang/365Gallery/fast-style-transfer

# %%
# !python evaluate.py \
    --checkpoint /Users/bangyoon/00_2021sogang/365Gallery/model/scream.ckpt \
    --in-path /Users/bangyoon/00_2021sogang/365Gallery/img/ \
    --out-path /Users/bangyoon/00_2021sogang/365Gallery/output \
    --allow-different-dimensions
# Out:
# Processing images of shape 610x780x3
# 2021-03-31 12:56:35.016081: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-03-31 12:56:35.257595: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:196] None of the MLIR optimization passes are enabled (registered 0 passes)
# 2021-03-31 12:56:35.260321: W tensorflow/core/common_runtime/colocation_graph.cc:1139] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# ...
