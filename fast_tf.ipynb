# %% [markdown]
# <a href="https://colab.research.google.com/github/365Gallery/ML/blob/main/fast_tf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/lengstrom/fast-style-transfer.git
# Out:
# Cloning into 'fast-style-transfer'...
# remote: Enumerating objects: 1, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 239 (delta 0), reused 0 (delta 0), pack-reused 238
# Receiving objects: 100% (239/239), 11.02 MiB | 45.86 MiB/s, done.
# Resolving deltas: 100% (111/111), done.

# %% [markdown]
# <h1>for using conda in Colab
# <h4>https://github.com/RogerHeederer/chatbot/blob/master/UsingColabWithConda.ipynb

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !which python
# Out:
# /usr/local/bin/python

# %%
# !python --version

#구글 코랩에 디폴트로 깔려 있는 python 3.6과 매칭이 되는 미니콘다를 깔아야 함
#그 미니콘다 버전은 4.5.4
# Out:
# Python 3.7.10

# %%
# !echo $PYTHONPATH
# Out:
# /env/python

# %%
#PYTHONPATH를 unset해야한다. 
#위에 처럼 세팅된 디렉토리로 놔두면, 접근 에러가 발생할 수 있다.
# %env PYTHONPATH=
# Out:
# env: PYTHONPATH=

# %% [markdown]
# <h1>install miniconda

# %%
# %%bash
#
# MINICONDA_INSTALLER_SCRIPT=Miniconda3-4.5.4-Linux-x86_64.sh
# MINICONDA_PREFIX=/usr/local
# wget https://repo.continuum.io/miniconda/$MINICONDA_INSTALLER_SCRIPT
# chmod +x $MINICONDA_INSTALLER_SCRIPT
# ./$MINICONDA_INSTALLER_SCRIPT -b -f -p $MINICONDA_PREFIX
# Out:
# PREFIX=/usr/local
# installing: python-3.6.5-hc3d631a_2 ...
# installing: ca-certificates-2018.03.07-0 ...
# installing: conda-env-2.6.0-h36134e3_1 ...
# installing: libgcc-ng-7.2.0-hdf63c60_3 ...
# installing: libstdcxx-ng-7.2.0-hdf63c60_3 ...
# installing: libffi-3.2.1-hd88cf55_4 ...
# installing: ncurses-6.1-hf484d3e_0 ...
# installing: openssl-1.0.2o-h20670df_0 ...
# installing: tk-8.6.7-hc745277_3 ...
# installing: xz-5.2.4-h14c3975_4 ...
# installing: yaml-0.1.7-had09818_2 ...
# installing: zlib-1.2.11-ha838bed_2 ...
# installing: libedit-3.1.20170329-h6b74fdf_2 ...
# installing: readline-7.0-ha6073c6_4 ...
# installing: sqlite-3.23.1-he433501_0 ...
# installing: asn1crypto-0.24.0-py36_0 ...
# installing: certifi-2018.4.16-py36_0 ...
# installing: chardet-3.0.4-py36h0f667ec_1 ...
# installing: idna-2.6-py36h82fb2a8_1 ...
# installing: pycosat-0.6.3-py36h0a5515d_0 ...
# installing: pycparser-2.18-py36hf9f622e_1 ...
# installing: pysocks-1.6.8-py36_0 ...
# ...

# %%
# !which conda
# Out:
# /usr/local/bin/conda

# %%
# !conda --version
# Out:
# conda 4.5.4

# %%
# !which python
# Out:
# /usr/local/bin/python

# %%
#미니 콘다가 설치된 후에는 파이썬 버젼이 살짝 바뀜
# !python --version
# Out:
# Python 3.6.5 :: Anaconda, Inc.

# %%
# Without 파이썬 업데이트, 아나콘다 최신 버젼으로 업데이트
# 즉 파이썬은 3.6버전으로 홀딩하고, 아나콘다 업데이트
# %%bash

conda install --channel defaults conda python=3.6 --yes
conda update --channel defaults --all --yes
# Out:
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - conda
#     - python=3.6
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     urllib3-1.26.4             |     pyhd3eb1b0_0          99 KB
#     pycosat-0.6.3              |   py36h27cfd23_0         107 KB
#     certifi-2020.12.5          |   py36h06a4308_0         144 KB
#     ncurses-6.2                |       he6710b0_1         1.1 MB
#     wheel-0.36.2               |     pyhd3eb1b0_0          31 KB
#     pyopenssl-20.0.1           |     pyhd3eb1b0_1          48 KB
#     _libgcc_mutex-0.1          |             main           3 KB
#     conda-package-handling-1.7.2|   py36h03888b9_0         967 KB
#     tk-8.6.10                  |       hbc83047_0         3.2 MB
#     six-1.15.0                 |     pyhd3eb1b0_0          13 KB
# ...

# %%
# !conda --version
# Out:
# conda 4.9.2

# %%
# !python --version
# Out:
# Python 3.6.13 :: Anaconda, Inc.

# %% [markdown]
# <h1>System Path 설정

# %%
import sys
sys.path
# Out:
# ['',
#  '/content',
#  '/env/python',
#  '/usr/lib/python37.zip',
#  '/usr/lib/python3.7',
#  '/usr/lib/python3.7/lib-dynload',
#  '/usr/local/lib/python3.7/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.7/dist-packages/IPython/extensions',
#  '/root/.ipython']

# %%
# !ls /usr/local/lib/python3.6/dist-packages

# %%
# Any package that you install with Conda will be installed into the directory
import sys
_ = (sys.path.append("/usr/local/lib/python3.6/site-packages"))

# %%
sys.path
# Out:
# ['',
#  '/content',
#  '/env/python',
#  '/usr/lib/python37.zip',
#  '/usr/lib/python3.7',
#  '/usr/lib/python3.7/lib-dynload',
#  '/usr/local/lib/python3.7/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.7/dist-packages/IPython/extensions',
#  '/root/.ipython',
#  '/usr/local/lib/python3.6/site-packages']

# %% [markdown]
# <h1>패키지 install

# %%
# !conda install --channel conda-forge featuretools --yes
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - featuretools
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     bokeh-1.4.0                |   py36h9f0ad1d_1        13.5 MB  conda-forge
#     ca-certificates-2020.12.5  |       ha878542_0         137 KB  conda-forge
#     certifi-2020.12.5          |   py36h5fab9bb_1         143 KB  conda-forge
#     click-7.1.2                |     pyh9f0ad1d_0          64 KB  conda-forge
#     cloudpickle-1.6.0          |             py_0          22 KB  conda-forge
#     conda-4.9.2                |   py36h5fab9bb_0         3.0 MB  conda-forge
#     contextvars-2.4            |             py_0          11 KB  conda-forge
#     cytoolz-0.11.0             |   py36h1d69622_1         368 KB  conda-forge
#     dask-2021.3.0              |     pyhd3eb1b0_0           5 KB
# ...

# %%
# !ls
# Out:
# drive  fast-style-transfer  Miniconda3-4.5.4-Linux-x86_64.sh  sample_data

# %%
# !conda env create -f /content/drive/MyDrive/capstone2/environment.yml
# Out:
# CondaValueError: prefix already exists: /usr/local/envs/stats

# %% [markdown]
# <h1>Build a virtual environment

# %%
# !conda create -n tf-gpu tensorflow-gpu=2.1.0
# Out:
# done
# failed with repodata from current_repodata.json, will retry with next repodata source.
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/tf-gpu
#
#   added / updated specs:
#     - tensorflow-gpu=2.1.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _tflow_select-2.1.0        |              gpu           2 KB
#     absl-py-0.12.0             |   py37h06a4308_0         171 KB
#     aiohttp-3.7.4              |   py37h27cfd23_1         536 KB
#     astor-0.8.1                |   py37h06a4308_0          47 KB
#     async-timeout-3.0.1        |   py37h06a4308_0          13 KB
#     attrs-20.3.0               |     pyhd3eb1b0_0          43 KB
#     blas-1.0                   |              mkl           6 KB
#     blinker-1.4                |   py37h06a4308_0          23 KB
#     brotlipy-0.7.0             |py37h27cfd23_1003         320 KB
# ...

# %%
# !conda install jupyterlab
# Out:
# done
# failed with initial frozen solve. Retrying with flexible solve.
# failed with repodata from current_repodata.json, will retry with next repodata source.
# done
# \
# ...
#   - defaults/linux-64::jedi-0.17.0-py36_0, defaults/noarch::parso-0.8.1-pyhd3eb1b0_0
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - jupyterlab
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     anyio-2.2.0                |   py36h06a4308_0         120 KB
#     argon2-cffi-20.1.0         |   py36h27cfd23_1          46 KB
#     async_generator-1.10       |   py36h28b3542_0          39 KB
#     babel-2.9.0                |     pyhd3eb1b0_0         5.5 MB
#     backcall-0.2.0             |     pyhd3eb1b0_0          13 KB
#     bleach-3.3.0               |     pyhd3eb1b0_0         113 KB
# ...

# %%
# !conda info
# Out:
#      active environment : None
#        user config file : /root/.condarc
#  populated config files :
#           conda version : 4.9.2
#     conda-build version : not installed
#          python version : 3.6.13.final.0
#        virtual packages : __cuda=11.2=0
#                           __glibc=2.27=0
#                           __unix=0=0
#                           __archspec=1=x86_64
#        base environment : /usr/local  (writable)
#            channel URLs : https://repo.anaconda.com/pkgs/main/linux-64
#                           https://repo.anaconda.com/pkgs/main/noarch
#                           https://repo.anaconda.com/pkgs/r/linux-64
#                           https://repo.anaconda.com/pkgs/r/noarch
#           package cache : /usr/local/pkgs
#                           /root/.conda/pkgs
#        envs directories : /usr/local/envs
#                           /root/.conda/envs
#                platform : linux-64
# ...

# %%
# !conda init bash
# Out:
# no change     /usr/local/condabin/conda
# no change     /usr/local/bin/conda
# no change     /usr/local/bin/conda-env
# no change     /usr/local/bin/activate
# no change     /usr/local/bin/deactivate
# no change     /usr/local/etc/profile.d/conda.sh
# no change     /usr/local/etc/fish/conf.d/conda.fish
# no change     /usr/local/shell/condabin/Conda.psm1
# no change     /usr/local/shell/condabin/conda-hook.ps1
# no change     /usr/local/lib/python3.6/site-packages/xontrib/conda.xsh
# no change     /usr/local/etc/profile.d/conda.csh
# modified      /root/.bashrc
#
# ==> For changes to take effect, close and re-open your current shell. <==

# %%
# !source ~/.bashrc

# %%
# !which python
#/usr/local/bin/python
# Out:
# /usr/local/bin/python

# %%
# %%bash
# source activate tf-gpu
#
# python
# import sys
# # maybe only need this the first time we run this notebook
# sys.path.append('/usr/local/lib/python3.6/site-packages')
#
# print("Python version")
# print(sys.version)
# Out:
# Python version
# 3.7.10 (default, Feb 26 2021, 18:47:35)
# [GCC 7.3.0]

# %%
# !jupyter lab
# Out:
# [I 2021-03-30 12:30:52.160 ServerApp] jupyterlab | extension was successfully linked.
# [W 2021-03-30 12:30:52.163 NotebookApp] 'allow_root' has moved from NotebookApp to ServerApp. This config will be passed to ServerApp. Be sure to update your config before our next release.
# [W 2021-03-30 12:30:52.163 NotebookApp] 'allow_root' has moved from NotebookApp to ServerApp. This config will be passed to ServerApp. Be sure to update your config before our next release.
# [W 2021-03-30 12:30:52.163 NotebookApp] 'port_retries' has moved from NotebookApp to ServerApp. This config will be passed to ServerApp. Be sure to update your config before our next release.
# [W 2021-03-30 12:30:52.163 NotebookApp] 'contents_manager_class' has moved from NotebookApp to ServerApp. This config will be passed to ServerApp. Be sure to update your config before our next release.
# ...

# %%
# !pip install moviepy==1.0.2
# Out:
# ...
#      |████████████████████████████████| 7.8 MB 10.6 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 69.4 MB/s
# ...
#      |████████████████████████████████| 26.9 MB 85 kB/s
# ...
#   Created wheel for moviepy: filename=moviepy-1.0.2-py3-none-any.whl size=110729 sha256=a4729feef2b1a2bca2a7f660d446bed40d9c45156b8ecd01c61650c0e5c632ae
#   Stored in directory: /root/.cache/pip/wheels/0e/90/bb/3721f0f2ff9dd187f734e751b9ad8e65271e831259a1ab11d4
# ...
#   Created wheel for proglog: filename=proglog-0.1.9-py3-none-any.whl size=6147 sha256=c212b8d4ff551ed5cd4bd565d8d3af94c1ad6dd2c8ec72f399c8f7192d0843e0
#   Stored in directory: /root/.cache/pip/wheels/e7/11/a0/7e65f734d33043735a557b1244569cca327353db9068158076
# Successfully built moviepy proglog
# ...

# %%
# !/content/fast-style-transfer/setup.sh
# Out:
# --2021-03-30 12:32:35--  http://www.vlfeat.org/matconvnet/models/beta16/imagenet-vgg-verydeep-19.mat
# Resolving www.vlfeat.org (www.vlfeat.org)... 64.90.48.57
# Connecting to www.vlfeat.org (www.vlfeat.org)|64.90.48.57|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://www.vlfeat.org/matconvnet/models/beta16/imagenet-vgg-verydeep-19.mat [following]
# --2021-03-30 12:32:35--  https://www.vlfeat.org/matconvnet/models/beta16/imagenet-vgg-verydeep-19.mat
# Connecting to www.vlfeat.org (www.vlfeat.org)|64.90.48.57|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 576042600 (549M)
# Saving to: ‘imagenet-vgg-verydeep-19.mat’
#
# imagenet-vgg-veryde 100%[===================>] 549.36M  34.8MB/s    in 16s
#
# 2021-03-30 12:32:52 (33.9 MB/s) - ‘imagenet-vgg-verydeep-19.mat’ saved [576042600/576042600]
#
# --2021-03-30 12:32:52--  http://msvocds.blob.core.windows.net/coco2014/train2014.zip
# ...

# %%
ls -l
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# -rw-rw-r-- 1 root root   77903 Aug 16  2014 COCO_train2014_000000275001.jpg
# -rw-rw-r-- 1 root root  105489 Aug 16  2014 COCO_train2014_000000275008.jpg
# -rw-rw-r-- 1 root root  129917 Aug 16  2014 COCO_train2014_000000275014.jpg
# -rw-rw-r-- 1 root root  122585 Aug 16  2014 COCO_train2014_000000275036.jpg
# -rw-rw-r-- 1 root root  193709 Aug 16  2014 COCO_train2014_000000275038.jpg
# -rw-rw-r-- 1 root root  148063 Aug 16  2014 COCO_train2014_000000275057.jpg
# -rw-rw-r-- 1 root root   84096 Aug 16  2014 COCO_train2014_000000275075.jpg
# -rw-rw-r-- 1 root root  142116 Aug 16  2014 COCO_train2014_000000275088.jpg
# -rw-rw-r-- 1 root root  215925 Aug 16  2014 COCO_train2014_000000275102.jpg
# -rw-rw-r-- 1 root root  234617 Aug 16  2014 COCO_train2014_000000275115.jpg
# -rw-rw-r-- 1 root root   93861 Aug 16  2014 COCO_train2014_000000275125.jpg
# -rw-rw-r-- 1 root root  181528 Aug 16  2014 COCO_train2014_000000275168.jpg
# ...

# %%
cd fast-style-transfer/
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-70-ca82a7047fac> in <module>()
# ----> 1 get_ipython().magic('cd fast-style-transfer/')
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py in magic(self, arg_s)
#    2158         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2159         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2160         return self.run_line_magic(magic_name, magic_arg_s)
#    2161
#    2162     #-------------------------------------------------------------------------
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line)
#    2079                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2080             with self.builtin_trap:
# -> 2081                 result = fn(*args,**kwargs)
# ...

# %%
# !python style.py --style /content/data/train2014/COCO_train2014_000000318189.jpg
# Out:
# Traceback (most recent call last):
#   File "style.py", line 5, in <module>
#     from optimize import optimize
#   File "src/optimize.py", line 3, in <module>
#     import vgg, pdb, time
#   File "src/vgg.py", line 3, in <module>
#     import tensorflow as tf
# ModuleNotFoundError: No module named 'tensorflow'

# %%
import tensorflow
print(tensorflow.__version__)
# Out:
# 2.4.1

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow is already loaded. Please restart the runtime to change versions.

# %%
# !conda activate tensorflow
# Out:
# CommandNotFoundError: Your shell has not been properly configured to use 'conda activate'.
# To initialize your shell, run
#
#     $ conda init <SHELL_NAME>
#
# Currently supported shells are:
#   - bash
#   - fish
#   - tcsh
#   - xonsh
#   - zsh
#   - powershell
#
# See 'conda init --help' for more information and options.
#
# IMPORTANT: You may need to close and restart your shell after running 'conda init'.

# %%
cd ../fast-style-transfer/
# Out:
# /content/fast-style-transfer

# %%
# !pip install tensorflow==2.4.1 --ignore-installed
# Out:
# ...
#      |████████████████████████████████| 394.3 MB 25 kB/s
# ...
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# ...
#      |████████████████████████████████| 3.8 MB 67.3 MB/s
# ...
#      |████████████████████████████████| 10.6 MB 70.6 MB/s
# ...
#   Using cached absl_py-0.12.0-py3-none-any.whl (129 kB)
# ...
#      |████████████████████████████████| 65 kB 4.7 MB/s
# ...
#   Using cached protobuf-3.15.6-cp36-cp36m-manylinux1_x86_64.whl (1.0 MB)
# ...
#   Using cached wheel-0.36.2-py2.py3-none-any.whl (35 kB)
# ...
#      |████████████████████████████████| 57 kB 6.2 MB/s
# ...
#   Using cached termcolor-1.1.0-py3-none-any.whl
# ...
#   Using cached numpy-1.19.5-cp36-cp36m-manylinux2010_x86_64.whl (14.8 MB)
# ...
#      |████████████████████████████████| 462 kB 64.0 MB/s
# ...
#   Using cached six-1.15.0-py2.py3-none-any.whl (10 kB)
# ...
#      |████████████████████████████████| 2.9 MB 65.1 MB/s
# ...
#   Using cached typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
# ...
#      |████████████████████████████████| 61 kB 9.1 MB/s
# ...

# %%
# !python evaluate.py --checkpoint /content/drive/MyDrive/capstone2/model/wave.ckpt --in-path /content/drive/MyDrive/capstone2/test/ --out-path /content/fast-style-transfer/output
# Out:
# 2021-03-30 13:29:08.309998: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-03-30 13:29:10.137472: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-03-30 13:29:10.151367: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-03-30 13:29:10.184531: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-30 13:29:10.185144: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# ...

# %%
cd ..
# Out:
# /content/fast-style-transfer

# %%
ls
# Out:
# chihiro025.jpg  chihiro043.jpg  howl012.jpg
# chihiro042.jpg  howl005.jpg     howl049.jpg

# %%
# !conda install -c conda-forge ffmpeg
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - ffmpeg
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     bzip2-1.0.8                |       h516909a_3         398 KB  conda-forge
#     ffmpeg-4.3.1               |       h3215721_1        83.4 MB  conda-forge
#     gmp-6.2.1                  |       h58526e2_0         806 KB  conda-forge
#     gnutls-3.6.13              |       h85f3911_1         2.0 MB  conda-forge
#     lame-3.100                 |    h14c3975_1001         498 KB  conda-forge
#     libiconv-1.16              |       h516909a_0         1.4 MB  conda-forge
#     nettle-3.6                 |       he412f7d_0         6.5 MB  conda-forge
#     openh264-2.1.1             |       h8b12597_0         1.5 MB  conda-forge
#     x264-1!152.20180806        |       h14c3975_0         1.4 MB  conda-forge
# ...

# %%
# !python transform_video.py --in-path /content/drive/MyDrive/capstone2/test/22.mp4 \
  --checkpoint /content/drive/MyDrive/capstone2/model/wave.ckpt \
  --out-path /content/fast-style-transfer/output/21output.mp4 \
  --device /gpu:0 \
  --batch-size 4
# Out:
# 2021-03-30 14:30:43.370459: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-03-30 14:30:45.535828: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-03-30 14:30:45.536962: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-03-30 14:30:45.571168: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-30 14:30:45.571780: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# ...
