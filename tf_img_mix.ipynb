# %% [markdown]
# <a href="https://colab.research.google.com/github/365Gallery/ML/blob/main/tf_img_mix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# If you are running in colab, select tensorflow version 1.x:

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %% [markdown]
# Or, if running locally, you need tensorflow version below 2

# %%
#!pip install -q 'tensorflow-gpu<2'

# %%
# !pip install -q 'scipy<=1.2.1'  # scipy.misc.imread is deprecated in later versions
# Out:
#      |████████████████████████████████| 24.8MB 119kB/s
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.

# %%
# !git clone https://github.com/titu1994/Neural-Style-Transfer.git
# Out:
# Cloning into 'Neural-Style-Transfer'...
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 1400 (delta 1), reused 3 (delta 0), pack-reused 1393
# Receiving objects: 100% (1400/1400), 68.16 MiB | 42.55 MiB/s, done.
# Resolving deltas: 100% (820/820), done.

# %%
dir_path = "Neural-Style-Transfer"

# %% [markdown]
# # Network Type
#
# Choose the network type below :
#
# - "Network" for the original style transfer
# - "INetwork" for the improved style transfer (default)

# %%
NETWORK = 'INetwork' + '.py'

# %%
# List all the arguments that can be supplied to Network.py
# !python {dir_path}/{NETWORK} -h
# Out:
# Using TensorFlow backend.
# usage: INetwork.py [-h] [--style_masks STYLE_MASKS [STYLE_MASKS ...]]
#                    [--content_mask CONTENT_MASK] [--color_mask COLOR_MASK]
#                    [--image_size IMG_SIZE] [--content_weight CONTENT_WEIGHT]
#                    [--style_weight STYLE_WEIGHT [STYLE_WEIGHT ...]]
#                    [--style_scale STYLE_SCALE]
#                    [--total_variation_weight TV_WEIGHT] [--num_iter NUM_ITER]
#                    [--model MODEL] [--content_loss_type CONTENT_LOSS_TYPE]
#                    [--rescale_image RESCALE_IMAGE]
#                    [--rescale_method RESCALE_METHOD]
#                    [--maintain_aspect_ratio MAINTAIN_ASPECT_RATIO]
#                    [--content_layer CONTENT_LAYER] [--init_image INIT_IMAGE]
#                    [--pool_type POOL] [--preserve_color COLOR]
#                    [--min_improvement MIN_IMPROVEMENT]
#                    base ref [ref ...] res_prefix
#
# Neural style transfer with Keras.
#
# positional arguments:
#   base                  Path to the image to transform.
#   ref                   Path to the style reference image.
#   res_prefix            Prefix for the saved results.
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --style_masks STYLE_MASKS [STYLE_MASKS ...]
#                         Masks for style images
#   --content_mask CONTENT_MASK
#                         Masks for the content image
#   --color_mask COLOR_MASK
#                         Mask for color preservation
#   --image_size IMG_SIZE
#                         Minimum image size
#   --content_weight CONTENT_WEIGHT
#                         Weight of content
#   --style_weight STYLE_WEIGHT [STYLE_WEIGHT ...]
#                         Weight of style, can be multiple for multiple styles
#   --style_scale STYLE_SCALE
#                         Scale the weighing of the style
#   --total_variation_weight TV_WEIGHT
#                         Total Variation weight
#   --num_iter NUM_ITER   Number of iterations
#   --model MODEL         Choices are 'vgg16' and 'vgg19'
#   --content_loss_type CONTENT_LOSS_TYPE
#                         Can be one of 0, 1 or 2. Readme contains the required
#                         information of each mode.
#   --rescale_image RESCALE_IMAGE
#                         Rescale image after execution to original dimentions
#   --rescale_method RESCALE_METHOD
#                         Rescale image algorithm
#   --maintain_aspect_ratio MAINTAIN_ASPECT_RATIO
#                         Maintain aspect ratio of loaded images
#   --content_layer CONTENT_LAYER
#                         Content layer used for content loss.
#   --init_image INIT_IMAGE
#                         Initial image used to generate the final image.
#                         Options are 'content', 'noise', or 'gray'
#   --pool_type POOL      Pooling type. Can be "ave" for average pooling or
#                         "max" for max pooling
#   --preserve_color COLOR
#                         Preserve original color in image
#   --min_improvement MIN_IMPROVEMENT
#                         Defines minimum improvement required to continue
#                         script

# %% [markdown]
# # Network Parameters
#
# Here, we will setup all of the parameters for the `Network.py` script.

# %%
# Image size
IMAGE_SIZE = 500

# Loss Weights
CONTENT_WEIGHT = 0.025
STYLE_WEIGHT = 1.0
STYLE_SCALE = 1.0
TOTAL_VARIATION_WEIGHT = 8.5e-5
CONTENT_LOSS_TYPE = 0

# Training arguments
NUM_ITERATIONS = 10
MODEL = 'vgg19'
RESCALE_IMAGE = 'false'
MAINTAIN_ASPECT_RATIO = 'false'  # Set to false if OOM occurs

# Transfer Arguments
CONTENT_LAYER = 'conv' + '5_2'  # only change the number 5_2 to something in a similar format
INITIALIZATION_IMAGE = 'content'
POOLING_TYPE = 'max'

# Extra arguments
PRESERVE_COLOR = 'false'
MIN_IMPROVEMENT = 0.0

# %% [markdown]
# # Content Image
#
# Run the below cell to upload the Content Image. Make sure to select **just 1 image**

# %%
from google.colab import files

content_img = files.upload()
# Out:
#      <input type="file" id="files-2c1ecfbb-7b0d-49d9-9cdc-e8570e537a27" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2c1ecfbb-7b0d-49d9-9cdc-e8570e537a27">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving howl049.jpg to howl049.jpg

# %%
import os

CONTENT_IMAGE_FN = list(content_img)[0]
CONTENT_IMAGE_FN_temp = CONTENT_IMAGE_FN.strip().replace(" ", "_")

if CONTENT_IMAGE_FN != CONTENT_IMAGE_FN_temp:
  os.rename(CONTENT_IMAGE_FN, CONTENT_IMAGE_FN_temp)
  CONTENT_IMAGE_FN = CONTENT_IMAGE_FN_temp
  
print("Content image filename :", CONTENT_IMAGE_FN)
# Out:
# Content image filename : howl049.jpg

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10, 10))
img = plt.imread(CONTENT_IMAGE_FN)
plt.axis('off')
plt.title('Content image')
plt.imshow(img)

# %% [markdown]
# # Style Image
#
# Run the below cell to upload the Style Image. Make sure to select **just 1 image**

# %%
style_img = files.upload()
# Out:
#      <input type="file" id="files-1134efad-d318-44cd-9714-fa1d1a76e9d6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1134efad-d318-44cd-9714-fa1d1a76e9d6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ban.jpg to ban.jpg

# %%
STYLE_IMAGE_FN = list(style_img)[0]
STYLE_IMAGE_FN_temp = STYLE_IMAGE_FN.strip().replace(" ", "_")

if STYLE_IMAGE_FN != STYLE_IMAGE_FN_temp:
  os.rename(STYLE_IMAGE_FN, STYLE_IMAGE_FN_temp)
  STYLE_IMAGE_FN = STYLE_IMAGE_FN_temp

print("Style image filename :", STYLE_IMAGE_FN)
# Out:
# Style image filename : ban.jpg

# %%
fig = plt.figure(figsize=(10, 10))
img = plt.imread(STYLE_IMAGE_FN)
plt.axis('off')
plt.title('Style image')
plt.imshow(img)

# %% [markdown]
# # Generate Image
#
# Run the below cells to generate the image

# %%
import os

RESULT_DIR = "generated/"
RESULT_PREFIX = RESULT_DIR + "gen"
FINAL_IMAGE_PATH = RESULT_PREFIX + "_at_iteration_%d.png" % (NUM_ITERATIONS)

if not os.path.exists(RESULT_DIR):
  os.makedirs(RESULT_DIR)

# %%
# !python {dir_path}/{NETWORK} {CONTENT_IMAGE_FN} {STYLE_IMAGE_FN} {RESULT_PREFIX} \
  --image_size {IMAGE_SIZE} --content_weight {CONTENT_WEIGHT} --style_weight \
  {STYLE_WEIGHT} --style_scale {STYLE_SCALE} --total_variation_weight \
  {TOTAL_VARIATION_WEIGHT} --content_loss_type {CONTENT_LOSS_TYPE} --num_iter \
  {NUM_ITERATIONS} --model {MODEL} --rescale_image {RESCALE_IMAGE} \
  --maintain_aspect_ratio {MAINTAIN_ASPECT_RATIO} --content_layer {CONTENT_LAYER} \
  --init_image {INITIALIZATION_IMAGE} --pool_type {POOLING_TYPE} --preserve_color \
  {PRESERVE_COLOR} --min_improvement {MIN_IMPROVEMENT}
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 2s 0us/step
# 2021-03-30 16:26:29.633746: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2021-03-30 16:26:29.689491: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-30 16:26:29.690157: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2021-03-30 16:26:29.699448: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-03-30 16:26:29.894562: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2021-03-30 16:26:30.042620: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2021-03-30 16:26:30.061573: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2021-03-30 16:26:30.345365: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2021-03-30 16:26:30.359798: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2021-03-30 16:26:30.878670: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-03-30 16:26:30.878861: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-30 16:26:30.879547: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-30 16:26:30.880063: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2021-03-30 16:26:30.946978: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2199995000 Hz
# 2021-03-30 16:26:30.947288: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x559871cbee00 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-03-30 16:26:30.947344: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2021-03-30 16:26:31.087472: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-30 16:26:31.088174: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x559871cbefc0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2021-03-30 16:26:31.088215: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2021-03-30 16:26:31.088416: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-30 16:26:31.088955: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2021-03-30 16:26:31.089019: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-03-30 16:26:31.089045: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2021-03-30 16:26:31.089069: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2021-03-30 16:26:31.089092: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2021-03-30 16:26:31.089111: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2021-03-30 16:26:31.089129: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2021-03-30 16:26:31.089148: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-03-30 16:26:31.089231: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-30 16:26:31.089815: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-30 16:26:31.090296: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2021-03-30 16:26:31.093349: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-03-30 16:26:31.095045: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-03-30 16:26:31.095080: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2021-03-30 16:26:31.095092: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2021-03-30 16:26:31.096141: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-30 16:26:31.096802: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-30 16:26:31.097347: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2021-03-30 16:26:31.097390: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14257 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# Model loaded.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/math_grad.py:1375: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Starting iteration 1 of 10
# 2021-03-30 16:26:42.588539: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2021-03-30 16:26:43.978533: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# Current loss value: 130519560.0  Improvement : 0.000 %
# Rescaling Image to (500, 924)
# Image saved as generated/gen_at_iteration_1.png
# Iteration 1 completed in 21s
# Starting iteration 2 of 10
# Current loss value: 61857930.0  Improvement : 52.606 %
# Rescaling Image to (500, 924)
# Image saved as generated/gen_at_iteration_2.png
# Iteration 2 completed in 10s
# Starting iteration 3 of 10
# Current loss value: 45133010.0  Improvement : 27.038 %
# Rescaling Image to (500, 924)
# Image saved as generated/gen_at_iteration_3.png
# Iteration 3 completed in 10s
# Starting iteration 4 of 10
# Current loss value: 38173460.0  Improvement : 15.420 %
# Rescaling Image to (500, 924)
# Image saved as generated/gen_at_iteration_4.png
# Iteration 4 completed in 10s
# Starting iteration 5 of 10
# Current loss value: 33423290.0  Improvement : 12.444 %
# Rescaling Image to (500, 924)
# Image saved as generated/gen_at_iteration_5.png
# Iteration 5 completed in 11s
# Starting iteration 6 of 10
# Current loss value: 30334586.0  Improvement : 9.241 %
# Rescaling Image to (500, 924)
# Image saved as generated/gen_at_iteration_6.png
# Iteration 6 completed in 11s
# Starting iteration 7 of 10
# Current loss value: 28601222.0  Improvement : 5.714 %
# Rescaling Image to (500, 924)
# Image saved as generated/gen_at_iteration_7.png
# Iteration 7 completed in 11s
# Starting iteration 8 of 10
# Current loss value: 26913376.0  Improvement : 5.901 %
# Rescaling Image to (500, 924)
# Image saved as generated/gen_at_iteration_8.png
# Iteration 8 completed in 11s
# Starting iteration 9 of 10
# Current loss value: 25721938.0  Improvement : 4.427 %
# Rescaling Image to (500, 924)
# Image saved as generated/gen_at_iteration_9.png
# Iteration 9 completed in 11s
# Starting iteration 10 of 10
# Current loss value: 24436452.0  Improvement : 4.998 %
# Rescaling Image to (500, 924)
# Image saved as generated/gen_at_iteration_10.png
# Iteration 10 completed in 11s

# %%
fig = plt.figure(figsize=(10, 10))
img = plt.imread(FINAL_IMAGE_PATH)
plt.axis('off')
plt.title('Generated image')
plt.imshow(img)

# %% [markdown]
# # (Optional) Color Transfer
#
# If you wish for color transfer between the content image and the generated image, then run the next cell, else skip to "Download Generated Image" section

# %%
COLOR_TRANSFER = 'color_transfer.py'
COLOR_FINAL_IMAGE_PATH = FINAL_IMAGE_PATH[:-4] + '_%s_color.png'

# Optional - Use Histogram matching (0 for no, 1 for yes)
HISTOGRAM_MATCH = 0

if HISTOGRAM_MATCH == 0:
  COLOR_FINAL_IMAGE_PATH = COLOR_FINAL_IMAGE_PATH % ('original')
else:
  COLOR_FINAL_IMAGE_PATH = COLOR_FINAL_IMAGE_PATH % ('histogram')
  

# !python {dir_path}/{COLOR_TRANSFER} {CONTENT_IMAGE_FN} {FINAL_IMAGE_PATH} --hist_match {HISTOGRAM_MATCH}
# Out:
# Neural-Style-Transfer/color_transfer.py:116: DeprecationWarning:     `imread` is deprecated!
#     `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use ``imageio.imread`` instead.
#   generated_image = imread(args.generated_image, mode="RGB")
# Neural-Style-Transfer/color_transfer.py:119: DeprecationWarning:     `imread` is deprecated!
#     `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use ``imageio.imread`` instead.
#   content_image = imread(args.content_image, mode=mode)
# Neural-Style-Transfer/color_transfer.py:120: DeprecationWarning:     `imresize` is deprecated!
#     `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.3.0.
#     Use Pillow instead: ``numpy.array(Image.fromarray(arr).resize())``.
#   content_image = imresize(content_image, (img_width, img_height), interp='bicubic')
# Neural-Style-Transfer/color_transfer.py:58: DeprecationWarning:     `toimage` is deprecated!
#     `toimage` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use Pillow's ``Image.fromarray`` directly instead.
#   generated = fromimage(toimage(generated, mode='RGB'), mode=mode)  # Convert to YCbCr color space
# Neural-Style-Transfer/color_transfer.py:58: DeprecationWarning:     `fromimage` is deprecated!
#     `fromimage` is deprecated in SciPy 1.0.0. and will be removed in 1.2.0.
#     Use ``np.asarray(im)`` instead.
#   generated = fromimage(toimage(generated, mode='RGB'), mode=mode)  # Convert to YCbCr color space
# Neural-Style-Transfer/color_transfer.py:78: DeprecationWarning:     `toimage` is deprecated!
#     `toimage` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use Pillow's ``Image.fromarray`` directly instead.
#   generated = fromimage(toimage(generated, mode=mode), mode='RGB')  # Convert to RGB color space
# Neural-Style-Transfer/color_transfer.py:78: DeprecationWarning:     `fromimage` is deprecated!
#     `fromimage` is deprecated in SciPy 1.0.0. and will be removed in 1.2.0.
#     Use ``np.asarray(im)`` instead.
#   generated = fromimage(toimage(generated, mode=mode), mode='RGB')  # Convert to RGB color space
# Neural-Style-Transfer/color_transfer.py:129: DeprecationWarning:     `imsave` is deprecated!
#     `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use ``imageio.imwrite`` instead.
#   imsave(image_path, img)
# Image saved at path : generated/gen_at_iteration_10_original_color.png

# %%
fig = plt.figure(figsize=(10, 10))
img = plt.imread(COLOR_FINAL_IMAGE_PATH)
plt.axis('off')
plt.title('Color Transferred Generated image')
plt.imshow(img)

# %% [markdown]
# # Download Color Transfered Image
#
# Run the following cell to download the color transferred result

# %%
# download the color transfered image
files.download(COLOR_FINAL_IMAGE_PATH)

# %% [markdown]
# # Download Generated Image
#
# Run the following cell to download the final result

# %%
files.download(FINAL_IMAGE_PATH)
